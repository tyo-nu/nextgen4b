# %%
# generate the runs for samples_all.yaml. The script we wrote isn't flexible enough.

n_experiments = 85
for k in range(n_experiments):
    i = k+1
    
    print 'run%i:' % i
    print '  experiments: [exp%i]' % i
    print '  f_read_name: Alexandra-%i-TC%i_S%i_L001_R1_001.fastq.gz' % (i, i, i)
    print '  filter_seqs:'
    if k == 0:
        print '    forward: &id002 [CATTGTCCCTAT, AGACCAAGTCTCTGCTACCGTA]'
        print "    reverse: &id003 ['']"
    else:
        print '    forward: *id002'
        print '    reverse: *id003'
    print '  pe_read_name: Alexandra-%i-TC%i_S%i_L001_R2_001.fastq.gz' % (i, i, i)
# Out:
# run1:
#   experiments: [exp1]
#   f_read_name: Alexandra-1-TC1_S1_L001_R1_001.fastq.gz
#   filter_seqs:
#     forward: &id002 [CATTGTCCCTAT, AGACCAAGTCTCTGCTACCGTA]
#     reverse: &id003 ['']
#   pe_read_name: Alexandra-1-TC1_S1_L001_R2_001.fastq.gz
# run2:
#   experiments: [exp2]
#   f_read_name: Alexandra-2-TC2_S2_L001_R1_001.fastq.gz
#   filter_seqs:
#     forward: *id002
#     reverse: *id003
#   pe_read_name: Alexandra-2-TC2_S2_L001_R2_001.fastq.gz
# run3:
#   experiments: [exp3]
#   f_read_name: Alexandra-3-TC3_S3_L001_R1_001.fastq.gz
#   filter_seqs:
#     forward: *id002
#     reverse: *id003
#   pe_read_name: Alexandra-3-TC3_S3_L001_R2_001.fastq.gz
# run4:
#   experiments: [exp4]
#   f_read_name: Alexandra-4-TC4_S4_L001_R1_001.fastq.gz
#   filter_seqs:
#     forward: *id002
#     reverse: *id003
#   pe_read_name: Alexandra-4-TC4_S4_L001_R2_001.fastq.gz
# run5:
#   experiments: [exp5]
#   f_read_name: Alexandra-5-TC5_S5_L001_R1_001.fastq.gz
#   filter_seqs:
# ...
